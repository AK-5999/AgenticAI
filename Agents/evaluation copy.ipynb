# %%
# Install dependencies (run once)
# !pip install langchain langchain-community langchain-core langgraph chromadb faiss-cpu sentence-transformers groq pydub speechrecognition pillow matplotlib pandas plotly
